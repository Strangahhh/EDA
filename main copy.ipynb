# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import title_is
from selenium.webdriver.support import expected_conditions as EC
import bs4
import time
import re

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Firefox()

driver.get('https://www.linkedin.com/feed/')

wait = WebDriverWait(driver, 10)

# original_window = driver.current_window_handle

# assert len(driver.window_handles) == 1

# driver.execute_script("document.body.style.transform='scale(0.1)';")
# driver.execute_script("document.body.style.transformOrigin='0 0';")

# time.sleep(2)

# driver.find_element(By.XPATH,'/html/body/center/div[3]/center/div/div[4]/a[4]').click()

# wait.until(EC.number_of_windows_to_be(2))

# for window_handle in driver.window_handles:
#         if window_handle != original_window:
#             driver.switch_to.window(window_handle)
#             break

# time.sleep(6)

# data = driver.page_source
# soup = bs4.BeautifulSoup(data)

# listrole = []
# listprovince = []
# listsalary_rate = []
# listjob_type = []
# listrequire = []
# listjob_details = []
# listjobqualifications = []

# P = soup.find_all("div",{"class":"w3-container w3-xlarge w3-center w3-theme-d5 w3-padding w3-text-shadow"}) 
# for c0 in P:
#     c0 = c0.text
#     listrole.append(c0)

# P = soup.find_all("div",{"class":"w3-container w3-left-align w3-medium w3-theme-l4"}) 
# for c1 in P:
#     c1 = c1.text
#     match = re.search(r'จังหวัด (.+?) \(', c1)
#     province = match.group(1) if match else None

#     match = re.search(r'อัตราค่าจ้าง (.+?)\รูปแบบงาน', c1)
#     salary_rate = match.group(1) if match else None

#     match = re.search(r'รูปแบบงาน (.+?)\อัตรา', c1)
#     job_type = match.group(1) if match else None

#     match = re.search(r'อัตรา (.+?)\อัตรา', c1)
#     require = match.group(1) if match else None

#     listprovince.append(province)
#     listsalary_rate.append(salary_rate)
#     listjob_type.append(job_type)
#     listrequire.append(require)

# P = soup.find_all("div",{"class":"w3-container w3-left-align w3-medium w3-theme-l5"}) 

# for c2 in P:
#     c2 = c2.text
#     job_details_pattern = re.compile(r'รายละเอียดงาน(.+?)คุณสมบัติผู้สมัคร', re.DOTALL)
#     job_details_match = job_details_pattern.search(c2)
#     if job_details_match:
#         job_details = job_details_match.group(1)
        
    
#     qualifications_pattern = re.compile(r'คุณสมบัติผู้สมัคร(.+?)วุฒิการศึกษาระดับ', re.DOTALL)
#     qualifications_match = qualifications_pattern.search(c2)
#     if qualifications_match:
#         qualifications = qualifications_match.group(1).strip()

#     listjob_details.append(job_details)
#     listjobqualifications.append(qualifications)

# df = pd.DataFrame()
# # df['JobID'] = ProductID
# df['RoleName'] = listrole
# df['Province'] = listprovince
# df['Salary_rate'] = listsalary_rate
# df['Job_type'] = listjob_type
# df['Require'] = listrequire
# df['Job_details'] = listjob_details
# df['jobqualifications'] = listjobqualifications

# driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Firefox()

driver.get('https://th.jobsdb.com')

wait = WebDriverWait(driver, 10)

original_window = driver.current_window_handle

assert len(driver.window_handles) == 1

driver.execute_script("document.body.style.transform='scale(0.1)';")
driver.execute_script("document.body.style.transformOrigin='0 0';")

time.sleep(2)

data = driver.page_source
soup = bs4.BeautifulSoup(data)

page_url = []


for page in range(1,12):
    
    driver.get(f'https://th.jobsdb.com/th/th/jobs/%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%A8%E0%B8%B2%E0%B8%AA%E0%B8%95%E0%B8%A3%E0%B9%8C-%E0%B8%87%E0%B8%B2%E0%B8%99-lab-%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%A7%E0%B8%B4%E0%B8%88%E0%B8%B1%E0%B8%A2%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%9E%E0%B8%B1%E0%B8%92%E0%B8%99%E0%B8%B2/{page}')

    driver.execute_script("document.body.style.transform='scale(0.1)';")
    driver.execute_script("document.body.style.transformOrigin='0 0';")
    
    data = driver.page_source
    soup = bs4.BeautifulSoup(data)

    class_name = "z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ii"
    h1_tags = soup.find_all("h1", class_=class_name)

    time.sleep(3)
    
    for h1_tag in h1_tags:
        a_tag = h1_tag.find('a')  # Find the first <a> tag within each <h1>
        if a_tag and a_tag.has_attr('href'):
            url = (f"https://th.jobsdb.com/{a_tag['href']}")
            page_url.append(url)
            # print(f"https://th.jobsdb.com/{a_tag['href']}")

    time.sleep(2)



    # /html/body/div[1]/div/div/div[3]/div[2]/div/div/div/div[1]/div/div/div/div/div[3]/div/a
    # /html/body/div[1]/div/div/div[3]/div[2]/div/div/div/div[1]/div/div/div/div/div[3]/div/a[2]

    # class_name = "z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ii"
    # h1_tags = soup.find_all("h1", class_=class_name)

    # for h1_tag in h1_tags:
    #     a_tag = h1_tag.find('a')  # Find the first <a> tag within each <h1>
    #     if a_tag and a_tag.has_attr('href'):
    #         url = (f"https://th.jobsdb.com/{a_tag['href']}")
    #         page_url.append(url)
    #         # print(f"https://th.jobsdb.com/{a_tag['href']}")

    # driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[3]/div[2]/div/div/div/div[1]/div/div/div/div/div[3]/div/a[2]').click()

# %%
len(page_url)
# Out:
# 327

# %%
file = open('งานด้านวิทยาศาสตร์.txt','w')
for item in page_url:
	file.write(item+"\n")
file.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Firefox()

driver.get('https://th.jobsdb.com')

wait = WebDriverWait(driver, 10)

original_window = driver.current_window_handle

assert len(driver.window_handles) == 1

driver.execute_script("document.body.style.transform='scale(0.1)';")
driver.execute_script("document.body.style.transformOrigin='0 0';")

time.sleep(2)

data = driver.page_source
soup = bs4.BeautifulSoup(data)

page_url = []


for page in range(1,105):
    
    driver.get(f'https://th.jobsdb.com/th/th/jobs/%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%82%E0%B8%B2%E0%B8%A2-%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%9A%E0%B8%A3%E0%B8%B4%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A5%E0%B8%B9%E0%B8%81%E0%B8%84%E0%B9%89%E0%B8%B2-%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%9E%E0%B8%B1%E0%B8%92%E0%B8%99%E0%B8%B2%E0%B8%98%E0%B8%B8%E0%B8%A3%E0%B8%81%E0%B8%B4%E0%B8%88/{page}')

    driver.execute_script("document.body.style.transform='scale(0.1)';")
    driver.execute_script("document.body.style.transformOrigin='0 0';")
    
    data = driver.page_source
    soup = bs4.BeautifulSoup(data)

    class_name = "z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ii"
    h1_tags = soup.find_all("h1", class_=class_name)

    time.sleep(3)
    
    for h1_tag in h1_tags:
        a_tag = h1_tag.find('a')  # Find the first <a> tag within each <h1>
        if a_tag and a_tag.has_attr('href'):
            url = (f"https://th.jobsdb.com/{a_tag['href']}")
            page_url.append(url)
            # print(f"https://th.jobsdb.com/{a_tag['href']}")

    time.sleep(2)

# %%
len(page_url)
# Out:
# 3113

# %%
file = open('งานบริการ-งานขาย.txt','w')
for item in page_url:
	file.write(item+"\n")
file.close()

# %%
datalinks = []

with open('IT.txt', 'r') as file:
    for line in file:
        datalinks.append(line.strip())

# %%
print(role)
print(company)
print(date_post)
print(career_level)
print(job_description)
print(highlight_job)
# Out:
# ['Officer/Senior Officer/Assistant Manager/Manager-Social Responsibility Management Department', 'Senior Program Manager', 'Resources Development Supervisor/หัวหน้าฝ่ายพัฒนาทรัพยากร', 'Humane Education Manager/ผู้จัดการฝ่ายการศึกษาเพื่อสวัสดิภาพสัตว์', 'Assistant Programme Manager (Chiang Mai)/ผู้ช่วยผู้จัดการโครงการร้อยใจรักษ์ จ.เชียงใหม่', 'Project Officer working in Kanchanaburi', 'ผู้ช่วยผู้จัดการฝ่าย หรือผู้จัดการส่วนประสานงานราชการ (อสังหาริมทรัพย์)', 'Administrative Assistant (Finance) in Hong Kong Economic and Trade Office (HKETO)/Applicants are invited to submit (i) Covering Letter and (ii) Curriculum Vitae in English', 'Agri-Forestry Project Manager', 'Senior Information Management Officer (National Position)', 'Permits & Licensing Officer/เจ้าหน้าที่ประสานงานใบอนุญาต', 'Project Officer - Mae Ping Forest in Lamphun', 'Project Manager - Mae Ping Forest Project', 'ADMIN BRANCH/แอดมินประจำสาขา', 'Bodyguard/Personal driver/บอดี้การ์ด/คนขับรถส่วนตัว', 'Legal: Associate - Manager ']
# ['The Stock Exchange of Thailand', 'ARD, Inc. (Head Office)', 'Raks Thai Foundation', 'Soi Dog Foundation', 'Mae Fah Luang Foundation Under Royal Patronage', 'World Wide Fund for Nature International: WWF', 'Lalin Property Public Company Limited', 'Hong Kong Economic and Trade Office in Bangkok', 'World Wide Fund for Nature International: WWF', 'International Rescue Committee', 'SPCG Public Company Limited', 'World Wide Fund for Nature International: WWF', 'World Wide Fund for Nature International: WWF', 'VJ MART CO., LTD.', 'HuntIT', 'Deloitte']
# ['Posted 13 hours ago', 'Posted on 18-Dec-23', 'Posted 13 hours ago', 'THB\xa035,000 - THB\xa045,000 /month ', 'Posted on 18-Dec-23', 'Posted on 18-Dec-23', 'Posted on 18-Dec-23', 'Posted on 15-Dec-23', 'Posted on 14-Dec-23', 'Posted on 13-Dec-23', 'Posted on 15-Dec-23', 'Posted on 13-Dec-23', 'Posted on 13-Dec-23', 'THB\xa013,000 - THB\xa016,000 /month ', 'THB\xa070,000 - THB\xa0120,000 /month ', 'Posted on 14-Dec-23']
# ['Entry Level', 'Top', 'Middle', 'Senior', 'Middle', 'Middle', 'Middle', 'Entry Level', 'Senior', 'Full Time', 'Entry Level', 'Middle', 'Senior', 'Full Time', 'Entry Level', 'Accounting/Audit/Tax Services']
# ['\xa0Bangkok 10400 Thailand', '', '\xa0', '19 annual holidays (including Thai National Holidays 13 days) rising to 25 days with year of serviceAnnual Salary AdjustmentAnnual Service bonus as policySocial SecurityProvident FundUniform', ' Chiang Mai)', '', 'Job Descriptionหน้าที่และความรับผิดชอบบริหารการขออนุญาตจัดสรรที่ดิน การยื่นจดทะเบียนอาคารชุด ออกโฉนดแปลงย่อยบริหารทีมงานเพื่อการจัดเตรียมเอกสารต่างๆ สำหรับการยื่นขออนุญาตจัดสรรที่ดิน\xa0 อาคารชุด เช่น ใบอนุญาตเชื่อมทาง ใบอนุญาตระบายน้ำ ฯลฯติดตามและตรวจสอบการเตรียมความพร้อมของระบบสาธารณูปโภคของโครงการบ้านจัดสรร รวมถึงระบบไฟฟ้าและระบบประปาบริหารการขออนุญาตก่อสร้างต่างๆ เช่น บ้าน อาคารชุด สะพาน ฯลฯดำเนินการติดต่อประสานงานหน่วยงานราชการที่เกี่ยวข้องทั้งหมดคุณสมบัติวุฒิการศึกษาระดับปริญญาตรี สาขานิติศาสตร์ หรือสาขาอื่นที่เกี่ยวข้องมีประสบการณ์อย่างน้อย 5 ปี ในธุรกิจอสังหาริมทรัพย์เกี่ยวกับงานด้านการติดต่อประสานงานราชการ การขออนุญาติต่าง ๆ จากหน่วยงานราชการมีทักษะความเป็นผู้นำ สามารถบริหารและพัฒนาทีมงานได้มีทักษะการติดต่อประสานงาน การเจรจาต่อรอง และการแก้ปัญหาสามารถขับรถยนต์ได้มีใบอนุญาตขับขี่รถยนต์ส่วนบุคคลสวัสดิการบริษัทกองทุนสำรองเลี้ยงชีพประกันสุขภาพหมู่ และอุบัติเหตุหมู่ค่ารักษาพยาบาล (ผู้ป่วยใน และผู้ป่วยนอก)ส่วนลดพิเศษซื้อบ้านในโครงการบริษัทฯเครื่องแบบพนักงาน (แจกทุกปี)รางวัลอายุงานค่าครองชีพ และค่าตำแหน่งเงินช่วยเหลือมงคลสมรสเงินช่วยเหลืออุปสมบทเงินช่วยฌาปนกิจครอบครัว และพนักงานของเยี่ยมกรณีคลอดบุตรของเยี่ยมกรณีรักษาตัวในโรงพยาบาลงานเลี้ยงสังสรรค์ปีใหม่ปรับค่าจ้าง และโบนัสประจำปีประกันสังคม และกองทุนเงินทดแทนท่านที่สนใจหรือต้องการสอบถามข้อมูลเพิ่มเติม โปรดติดต่อแผนกสรรหาดังรายละเอียดด้านล่างนี้คุณสุรเดช 081-870-9111 คุณณฐพร 087-970-3854 คุณณัฐพล 065-502-0746\xa0หรือ แผนกสรรหาบุคคล 02-732-1041-5 ต่อ 207', '', '', '', ' สามารถทำงานภายใต้สภาวะความกดดันและเร่งด่วนได้เป็นอย่างดี', '', '', ' รวบรวมและคีย์ข้อมูลต่างๆ- ประสานงานทั่วไป- แยกบิลเอกสารค่าใช้จ่าย- ดูแลความเรียบร้อยในสาขา- งานอื่นๆตามที่ได้รับมอบหมาย', '']
# ['สามารถเดินทางไปปฏิบัติงาน และพักค้างคืนต่างจังหวัด', 'Local capacity development', 'Analyze large data', 'Salary start 42K, Five-day work a week', 'Willingness to travel for field work', 'Contract 12 Months with possibility for extension', 'บริษัทมีความมั่นคง รายได้ดีและสวัสดิการหลากหลาย', 'Salary from THB 40,401 per month', 'Contract 12-month with possibility to extend', 'Communication and Data Visualization', 'Competitive Salary and Good benefits', 'Contract 12 months with possibility for extension', '12-month with possibility for extension', 'ยินดีรับนักศึกษาจบใหม่', 'Personal security and transportation', 'Personal security and transportation']

# %%
# df['jobqualifications'] = listjobqualifications

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import csv

role = []
company = []
date_post = []
highlight_job = []
career_level = []
qualification = []
exp = []
job_type = []
job_description = []
for datalink in datalinks:

    driver = webdriver.Firefox()

    driver.get(f'{datalink}')

    wait = WebDriverWait(driver, 10)

    original_window = driver.current_window_handle

    assert len(driver.window_handles) == 1

    driver.execute_script("document.body.style.transform='scale(0.1)';")
    driver.execute_script("document.body.style.transformOrigin='0 0';")

    time.sleep(2)

    data = driver.page_source
    soup = bs4.BeautifulSoup(data)
    
    time.sleep(1)

    #Role
    class_name = "z1s6m00 _1hbhsw64y y44q7i0 y44q7il _1d0g9qk4 y44q7is y44q7i21"
    h1 = soup.find("h1", class_=class_name)

    if h1:
        role1 = h1.get_text()
        print("role :", role1)
    else:
        print("-")    
    role.append(role1)
    #Company
    span = soup.find("span", class_="z1s6m00 _1hbhsw64y y44q7i0 y44q7i2 y44q7i21 _1d0g9qk4 y44q7ia")

    if span:
        company1 = span.get_text()
        print("Company :", company1)
    else:
        print("-")
    company.append(company1)

    #DATETIME
    span = soup.find_all("span", class_="z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 y44q7ii")

    if span:
        datetime = span[4].get_text()
        print("Date-post :", datetime)
    else:
        print("-")
    date_post.append(datetime)

    #highlight
    div = soup.find_all("div", class_="z1s6m00 _1hbhsw6r _1hbhsw6p _1hbhsw6a2")
    divselect = div[2:5]
    hl = [div.get_text(strip=True) for div in divselect]
    for h in hl:
        print(f'{h}')
    highlight_job.append(h)
    
    #career
    span1 = soup.find_all("span", class_="z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 _1d0g9qk4 y44q7ia")
    span1select = span1[15:19]
    textspan1 = [span1.get_text(strip=True) for span1 in span1select]
    for textspan in textspan1:
        print(f'{textspan}')
    career_level.append(textspan1[0])
    qualification.append(textspan1[1])
    exp.append(textspan1[2])

    #JobQ
    div1 = soup.find_all("div", class_="z1s6m00 _5135ge0 _5135ge2")
    jobQ = div1[1].get_text()
    
    sentences = re.split(r'[,.:;]', jobQ)

    for sentence in sentences:
        print(sentence.strip())
    job_description.append(sentence)
    driver.quit()
# Out:
# role : IT Support/ฝ่ายสนับสนุนด้านไอที
# Company : Aver Asia (Thailand) Limited
# Date-post : Posted 13 hours ago
# 2-4 years' experience in IT services and support
# Must be able to communicate well in English.
# Technical support across the local branches.
# Entry Level
# Diploma of High Vocational Education
# 2 years
# Full Time, Permanent
# Job DescriptionType of business
# Trading
# Rental and Service Machinery     Duties / Responsibilities
# Installing and configuring computer hardware
# software
# systems
# networks
# printers
# and scanners
# Monitoring and maintaining computer systems and networks
# Responding in a timely manner to service issues and requests
# Providing technical support across the company
# Manage all the branches infra systems and support users remotely as well as visiting branches as per schedule
# Support ERP system for the end users
# Required Qualifications
# Must be able to communicate well in English
# 1-2 years of ERP support experienceMinimum Diploma in Information Technology or equivalent
# 2 to 4 years of related working experience
# Good communication skills and ability to work independently
# also as a teamExperience in SharePoint
# Microsoft Office 365 will be an advantage
# Willing to travel to branches when needed
# Working Date and Working Time
# Mon - Fri  08
# 00 am
# -17
# 30 pm
# Alt Saturdays 08
# 00 am
# – 12
# 00 pm
# Benefit
# Medical fee
# Provident Fund
# Incentive
# Bonus
# Group Insurance
# Annual travelLocation
# 238/8 Moo 5
# Bangna-Trad Road KM 30
# Bang Bo
# Bang Bo
# Samutprakarn 10560Website
# www
# averasiathailand
# comTelephone
# 02-1300-755 - 58Contact Person
# K
# Game (Mobile) 063-391-4443
# role : Lead Enterprise Architecture
# Company : Thai Credit Bank PLC.
# Date-post : Posted 23 hours ago
# Enterprise Architecture
# ARB (Architecture Review Board)
# Hybrid Working, Near MRT, Bank
# Top
# Degree
# 10 years
# Temporary, Contract
# Job DescriptionJob Descriptions
# Setup the Enterprise Architecture framework for the bank
# with initial focus to set up the foundation in IT
# build the inventory for all key artifacts
# Support and facilitate the ARB (Architecture Review Board)
# Work closely with IT functional lead to drive architectural standards and provide support and tools to benefit from the enterprise architecture framework
# Job Qualifications
# Minimum 10 years of IT experienceWell verse in the Enterprise Architecture framework/practice
# Any related certification of the EA discipline will be an added advantagePractice EA or relevant discipline for at least 2 years
# Banking or Financial Institution background is preferred but not a must
# Excellent interpersonal skill in managing stakeholders and peer groups
# Bachelor/Master degree in IT or related disciplineHighly self motivated and be able to work independently
#
# role : Assistant Manager - System Engineer
# Company : Tokio Marine Life Insurance (Thailand) Public Company Limited
# Date-post : Posted 13 hours ago
# System Engineer designed and installing
# System runs smoothy and efficiently and resolve
# Flexible Working hours, Work From Home
# Middle
# Degree
# 3 years
# Full Time, Permanent
# Job DescriptionJob Summary
# System engineer is responsible for designing and installing an organization's networked computer infrastructure
# This is to ensure that the system runs smoothly and efficiently and resolve any technical issues that may arise
# IT security to protect computer systems and data from intruders
# Maintain IT security to protect computer systems and data from intruders
# Jobs Qualification
# Bachelor's or master's in computer engineer or relevant fields
# 3 - 5 years of experience as Administrator in system / network / security
# Experience in Virtualization and containerization (e
# g
#
# VMware)Experience with MS Active directory
# backup systems and monitoring systems
# Great attention to detail and time management skills
# Good command of spoken and written English (TOEIC score 300)Life insurance experience would be advantage
# Certified IT Services or Security such as ITIL
# ITSM
# CISM
# CISSP
# CompTIA Security+ is a plusBenefit & WelfarePerformance BonusAnnual LeaveEnbloc LeaveProvident FundLife Insurance & Health Insurance (OPD
# IPD) including Spouse and ChildDental & Eyeglasses – LensesOverseas Outing TripFlexible Working HoursWork From Home
# role : Internship Student Software Engineer
# Company : Yannix Co., Ltd. (Head Office)
# Date-post : Posted on 18-Dec-23
# Opportunity to work in Tech Company from USA
# Our vfx programming team uses Python / C++
# 3rd or 4th year of university student.
# Degree
# N/A
# Full Time, Internship
# http://www.yannix.com
# Job DescriptionJob Descriptions
# Design workflow and implement applications per gathered requirements
# Research new technologies/methodologies
# conduct experiments
# evaluate the findings/results
# and put into practice
# Maintain
# optimize
# and re-factor existing software and fix bugs
# Build and deploy production software
# Build and maintain applications including writing code
# solving problems
# exploring new technologies
# and creating better user experiences
# Qualifications
# Bachelor's degree in Computer Science
# Computer Engineering
# or related field
# New graduates are welcome
# Good communications and interpersonal skills
# Good Command in English
# Key Competencies
# Be strong in coding (Python
# C++
# data structure and algorithm) with excellent problem solving skills
# Be familiar with software development process (version control
# code review
# release management)
# Be enthusiastic and passionate
# Possess excellent communications (in English) and interpersonal skills
# Benefits and Allowances
# AllowanceSpecial Food
# Coffee
# SnackMovie nightShuttle BusBoard Game
# role : Senior Manager, Project Management
# Company : Lotus's
# Date-post : Posted 13 hours ago
# Develops and supports the virtual IT PMO
# Experience in software engineering or a related
# Experience in technical project management
# Senior
# Degree
# 10 years
# Full Time, Permanent
# Job DescriptionKey Responsibilities
# Define the projects objectives and oversee quality control throughout its life cycle
# This role will gain organizational commitment for all systems and plans
# as well as evaluate and select all technologies required to complete those plans
# Prepares project plans and makes scheduling decisions for IT projects
# manages active
# pending
# and proposed projects for IT
# reviews the status of all assigned projects
# Works closely with managers and directors to set priorities
# coordinate work efforts
# and report project activities
# Facilitates the orderly and efficient capture
# storage
# processing
# and dissemination of information regarding ongoing or upcoming projects
# communicates the status of key projects
# Prepares regular reports on the status of deployment and implementation projects to which they are assigned
# presents to various groups on status and implications of the implementation and deployment processes
# Assesses and manages risks
# and makes recommendations to keep projects on track
# Assures proper documentation and communication of necessary controls
# creates metrics and measurements that will be used in the implementation and deployment process to validate the achievement of objectives on a per-project basis
# Develops and manages effective working relationships with other departments
# groups and personnel with whom work must be coordinated or interfaced
# Provides consulting support to enterprise and IT customers (both internal and external) to maximize project implementation effectiveness
# Interfaces with vendors for purchasing
# support
# and consulting services as needed
# Assists in developing long-range information technology strategy
# Works with managers and directors to develop departmental project budgets based on forecasted human resources
# software
# and hardware requirements
# Prepares
# documents
# and maintains IT workflows
# design processes and checklists for projects to ensure accurate tracking and adherence to IT standards architecture as well as IT staff accountability for successful project completion
# Implements and deploys enterprises IT infrastructure installations
# modifications
# upgrades and improvements
# Develops and supports the virtual IT PMO with collaboration and input from IT managers
# Contribute at a design level to project efforts as appropriate
# bringing in necessary talent to evaluate changes and proposals
# Provides technical leadership as needed
# Provides mentorship and guidance to project team leaders and members
# Stays familiar with new technologies
# processes and techniques for project management and be prepared to guide their introduction into the teams
# Qualifications
# Bachelors Degree in Computer Science
# Engineering
# Business Management or a related discipline10 years of progressive experience in technical project management or associate's degree with 8 years of progressive experience in technical project management
# Experience in software engineering or managing enterprise-scale projects
# Expertise and experience with standard software engineering practices and software lifecycle management
# Familiarity with Agile methodology in software development
# Outstanding organization skills to track a variety of ongoing projects in a busy environment
# Well-rounded understanding of enterprise information technologyHands-on experience with business requirements gathering and analysisStrong understanding of information processing principles and practicesProven project planning and management experience leading large
# complex
# cross-functional projectsExperienced working in a team-oriented
# collaborative environmentAbility and willingness to thoroughly understand and embrace the organizations goals and objectivesDemonstrated leadership and people management skills
# Exceptional analytical
# conceptual
# and problem-solving abilitiesProactive and proficient at making informed decisions in a timely mannerSuperior oral and written communication skills including technical support documentation creation and editingAble to present ideas in user-friendly language
# communicating clearly to non-technical audiencesStrong interpersonal and consultative skills including conflict resolution proficiencyCapable of prioritizing and executing tasks in a high-pressure environmentEffective at tracking lessons learned and sharing those lessons with team membersIdentifies opportunities for improvement and makes constructive suggestions for changeSkilled at enabling team interaction
# boosting employee morale
# and appreciating team contributionSolid customer relationship and performance management skillsCommunicates effectively with clients to identify needs and evaluate alternative technical solutionsKnowledge of and experience with contracting and negotiating
# Lotus'sEk-Chai Distribution System Co
#
# Ltd
# Buengkum
# Bangkok 10230
# Thailand“By applying for this position
# you consent to the collection
# use and disclosure of your personal data to us
# our recruitment firms and all relevant third parties for the purpose of processing your application for this job position (or any other suitable positions within Lotus's and its subsidiaries
# if any)
# You understand and acknowledge that your personal data will be processed in accordance with the law and our policy
# ”
# role : IT Manager/IT Manager
# Company : Bridgestone Specialty Tire Manufacturing (Thailand) Co., Ltd.
# Date-post : Posted on 18-Dec-23
# IT Manager
# IT system
# Management Level
# Senior
# Degree
# 18 years
# Full Time, Permanent
# Job DescriptionJob DescriptionImplement IT system with policies
# Analyze
# design
# develop IT Project such as cyber security plan
# system maintenance plan and IT procedures
# Coordinate with Bridgestone Group in Japan and Singapore
# Manage and support IT member
# Handle IT budget
# Support internal and external Audit
# QualificationBachelor's degree or higher in Computer science
# Information Technology
# Computer Engineering or related fields
# At least 13 years's experience in IT department in Manufacturing
# At least 5 years's experience in Manager level
# Knowledeg and experience about Operation system
# Hardware
# software
# Server
# Computer
# Network
# Electrical Power
# Excellent English communication skill
# (speaking
# reading
# writing
# )Basic Japanese will be advantage
#
# role : IT Manager / Assistant IT Manager/ผู้จัดการฝ่าย IT/ผู้ช่วยผู้จัดการฝ่าย IT
# Company : TN GROUP CORPORATION CO., LTD
# Date-post : Posted 22 hours ago
# ISO 27001
# SAP S/4HANA
# IT systems, infrastructure, andemerging technology
# Senior
# Degree
# 5 years
# Full Time, Permanent
# Job DescriptionResponsibilities
# - Develop and implement IT strategies
# - Prepare and present the annual IT budget
# - Monitor and manage IT expenditures
# - Create clear documentation for each IT policy
# - Enforcing IT policies and monitor compliance
# - Implement tools and technologies that support policy enforcement
# - Oversee the day-to-day operations of the IT department
# ensuring the delivery of high-quality services and support
# - Delegate tasks and responsibilities to IT staff based on their strengths and expertise
# - Conduct regular performance evaluations and provide constructive feedback to enhance team performance
# - Lead IT projects from conception to completion
# ensuring timely delivery and successful implementation
# - Collaborate with cross-functional teams to achieve project goals and milestones
# Qualifications
# - Bachelor’s degree in information technology
# Computer Science
# or a related field
# - 5 years in a leadership role within the IT domain
# - Strong understanding of IT systems
# infrastructure
# and emerging technologies
# - Excellent communication and interpersonal skills
# - ISO 27001 and IT General Controls (ITGC) proficiency are highly advantageous
# - Experience in Project Management would be an advantage
# - Experience in SAP S/4HANA in any module would be an advantage
#
# role : IT Infrastructure - Manager / Officer
# Company : Mitsubishi Elevator (Thailand) Co., Ltd.
# Date-post : Posted on 18-Dec-23
# IT Infrastructure, System Administrator
# Cloud Server (AWS, Azure) OS (Window, Linux, AS400
# Good communication in English.
# Entry Level
# Degree
# 5 years
# Full Time
# Job DescriptionResponsibilities
# Installing and configuring software
# hardware
# and networksMonitoring system performance and troubleshooting issuesEnsuring security and efficiency of IT infrastructure
# Managing user accounts and permissions
# Implementing and maintaining security measures
# Providing technical support to users
# Managing system security (e
# g
# intrusion detection systems) and data backup/recovery
# Managing database
# networks
# and patch management
# Managing O365 (Microsoft Office
# Team
# SharePoint
# One Drive and etc
# )
# Managing Active Directory
# Group Policy
# DNS
# DHCP
# VMware
# etc
# Oversee data backup and system security operations (e
# g
# user authorization
# firewalls)
# Assess system performance and recommend improvements
# Manage contracts with vendors and software licensesControl costs and budgets regarding IT systems
# Develop IT policies and practices
# Other duties as assigned
# Qualifications
# Bachelor’s degree in computer science or related field
# Proven experience as a System Administrator
# Network Administrator
# or similar role
# Have skills in solving problems
# Excellent communication and interpersonal skillsGood communication in English
# (TOEIC Score 500+ will be preferred)Able to quickly grasp and understand new tasks
# Able to analyze the root cause of problems and find interim or permanent solutions
# Able to work well as part of a team
# Able to meet multiple deadlines
# Detail-oriented
# with a can-do attitude
# Proficiency in Microsoft Office Suite
# Possess a strong desire for self-improvement and advancement
# Computer Skill
# MS Office (Word
# Excel
# Power Point)Cloud Server (AWS
# Azure
# etc
# )OS (Window
# Linux
# Unix
# AS400)MITSUBISHI ELEVATOR (THAILAND) CO
#
# LTD
# 9-10
# 12 Floor
# Bangna Towers A
# 2/3 Moo 14 Debaratna Road
# Bangkaew
# Bangplee
# Samutprakarn 10540Tel
# 02-315-8201
# Fax
# 02-312-0800Website
# https
# //www
# mitsubishielevator
# co
# th/
# role : IT Support Officer (Welcome new graduation)
# Company : Deloitte Touche Tohmatsu Jaiyos Co., Ltd.
# Date-post : Posted on 18-Dec-23
# 0-3 years experience in IT support(new graduation)
# Good technical knowledge in computer hard/software
# Good English communication both writing/speaking
# Entry Level
# Degree
# N/A
# Full Time, Permanent
# Job DescriptionJob Descriptions
# Provides technical support on computer hardware and software in a corporate network environment
# Identifies
# researches
# and resolves technical problems
# Responds to telephone calls
# email and personnel requests for technical support
# Documents
# tracks and monitors the problem to ensure a timely resolution
# Reports to IT managers
# Qualifications
# Bachelor’s degree in Information Technology
# Computer Science or related area0-3 years of working experience in the IT support field or in a related area
# (Welcome new graduation)Working English communication skill
# Good technical knowledge in computer hardware and software
# Mature
# reliable
# service oriented
# and have ability to work under pressures
#
# role : IT Manager (Implementation and Service)
# Company : Touch Technologies Co., Ltd.
# Date-post : Posted on 18-Dec-23
# Salary: 50K - 65K
# IPD, OPD
# Near MRT: Phra Ram 9 Station
# Senior
# Degree
# N/A
# Full Time, Permanent
# Job DescriptionResponsibilitiesด้านเครือข่าย (Networking)วางแผนการติดตั้งและปรับปรุงระบบเครือข่ายคอมพิวเตอร์จัดให้มีระบบรักษาความปลอดภัยในเครือข่ายตามนโยบายของบริษัทดูแล บำรุงรักษาและบริหารจัดการโครงสร้างพื้นฐานระบบเครือข่ายดูแลและบริหารจัดการการเชื่อมต่อโครงข่ายคอมพิวเตอร์ระยะไกล (WAN)ด้านการบำรุงรักษา (Maintenance)ดูแลและบริหารจัดการบำรุงรักษาระบบคอมพิวเตอร์ ทั้งซอฟท์แวร์/ฮาร์ดแวร์ด้านการฝึกอบรม (Training)ส่งเสริมและสนับสนุนการฝึกอบรมทางด้านคอมพิวเตอร์แก่ผู้ใช้งานด้านระบบภายใน (Internal Systems)ดูแลการแก้ปัญหา การสำรองข้อมูล การกู้คืนระบบ และจัดหาผู้เชี่ยวชาญมาสนับสนุนเมื่อมีความจำเป็นประสานงานกับหน่วยงานต่าง ๆ ที่เกี่ยวข้องกับระบบคอมพิวเตอร์และระบบเครือข่ายด้านการจัดการทรัพยากรคอมพิวเตอร์ (Asset Management)บริหารจัดการการจัดซื้อซอฟท์แวร์และฮาร์ดแวร์ รวมทั้งสร้างความสัมพันธ์ที่ดีด้านการจัดการแก้ไขปัญหาและให้คำปรึกษา (Help Desk Administration)ตอบสนองความต้องการใช้งานระบบให้ความช่วยเหลือที่เพิ่มขึ้นช่วยแก้ไขปัญหาและให้คำปรึกษาการใช้งานคอมพิวเตอร์แก่ผู้ใช้งานให้ทันเวลาโดยมิให้งานเสียหายด้านการสื่อสารในหน่วยงานจัดให้มีการประชุมในทีมงานอย่างสม่ำเสมอเพื่อเพิ่มประสิทธิภาพในการปฎิบัติงานแจ้งข่าวความเคลื่อนไหวในองค์กรทั้งเรื่องทั่วไปและเรื่องเทคโนโลยีสารสนเทศให้แก่ทีมงานนำเสนอข้อมูลข่าวสารและกิจกรรมการปฎิบัติงานให้หน่วยงานอื่นได้รับรู้นำเสนอความก้าวหน้าในวงการเทคโนโลยีสารสนเทศแก่องค์กรอย่างสม่ำเสมอด้านการจัดการมีความคิดริเริ่มสร้างสรรค์ ปรับปรุง เปลี่ยนแปลงในงานที่รับผิดชอบสนับสนุนงานด้านไอทีตามที่ได้รับมอบหมายจากผู้บริหารรวบรวมข้อมูล วิเคราะห์แนวโน้มกฎหมายทางด้านไอที เพื่อกำหนดเป็นมาตรฐานสำหรับใช้ในองค์กรให้สอดคล้องกับกฎหมายดังกล่าวQualificationBachelor's degree or higher in Computer Science
# Information Technology
# IT Management or related fields
# Experience in Network
# Systems Administrator
# System Engineer (Microsoft
# Unix
# Linux
# VMware
# Hyper-V
# Oracle VM)Proven experience as a Head of IT or similar leadership roleStrong personal leadership and communication abilities - while empowering others to grow and deliver resultsDelivers on commitments (such as SLAs
# projects) through operational excellenceKnowledge of technological trends to build strategyUnderstanding of budgets and business-planningKnowledge and experience of PM
# analysis
# and reporting-related toolsBe a logical problem solver and demonstrable good leadership skills

# %%
df = pd.DataFrame()
df['RoleName'] = role
df['Company'] = company
df['Date_post'] = date_post
df['Highlight_job'] = highlight_job
df['Career_level'] = career_level
df['Qualification'] = qualification
# df['Exp'] = exp

# %%
df
# Out:
#                                              RoleName  \
# 0   Officer/Senior Officer/Assistant Manager/Manag...
# 1                              Senior Program Manager
# 2   Resources Development Supervisor/หัวหน้าฝ่ายพั...
# 3   Humane Education Manager/ผู้จัดการฝ่ายการศึกษา...
# 4   Assistant Programme Manager (Chiang Mai)/ผู้ช่...
# 5             Project Officer working in Kanchanaburi
# 6   ผู้ช่วยผู้จัดการฝ่าย หรือผู้จัดการส่วนประสานงา...
# 7   Administrative Assistant (Finance) in Hong Kon...
# 8                       Agri-Forestry Project Manager
# 9   Senior Information Management Officer (Nationa...
# 10  Permits & Licensing Officer/เจ้าหน้าที่ประสานง...
# 11       Project Officer - Mae Ping Forest in Lamphun
# 12          Project Manager - Mae Ping Forest Project
# 13                       ADMIN BRANCH/แอดมินประจำสาขา
# 14  Bodyguard/Personal driver/บอดี้การ์ด/คนขับรถส่...
# 15                        Legal: Associate - Manager
#
#                                            Company  \
# 0                   The Stock Exchange of Thailand
# 1                          ARD, Inc. (Head Office)
# 2                             Raks Thai Foundation
# 3                               Soi Dog Foundation
# 4   Mae Fah Luang Foundation Under Royal Patronage
# 5    World Wide Fund for Nature International: WWF
# 6            Lalin Property Public Company Limited
# 7   Hong Kong Economic and Trade Office in Bangkok
# 8    World Wide Fund for Nature International: WWF
# 9                   International Rescue Committee
# 10                     SPCG Public Company Limited
# 11   World Wide Fund for Nature International: WWF
# 12   World Wide Fund for Nature International: WWF
# 13                               VJ MART CO., LTD.
# 14                                          HuntIT
# 15                                        Deloitte
#
#                            Date_post  \
# 0                Posted 13 hours ago
# 1                Posted on 18-Dec-23
# 2                Posted 13 hours ago
# 3    THB 35,000 - THB 45,000 /month
# 4                Posted on 18-Dec-23
# 5                Posted on 18-Dec-23
# 6                Posted on 18-Dec-23
# 7                Posted on 15-Dec-23
# 8                Posted on 14-Dec-23
# 9                Posted on 13-Dec-23
# 10               Posted on 15-Dec-23
# 11               Posted on 13-Dec-23
# 12               Posted on 13-Dec-23
# 13   THB 13,000 - THB 16,000 /month
# 14  THB 70,000 - THB 120,000 /month
# 15               Posted on 14-Dec-23
#
#                                         Highlight_job  \
# 0   สามารถเดินทางไปปฏิบัติงาน และพักค้างคืนต่างจัง...
# 1                          Local capacity development
# 2                                  Analyze large data
# 3              Salary start 42K, Five-day work a week
# 4                Willingness to travel for field work
# 5   Contract 12 Months with possibility for extension
# 6     บริษัทมีความมั่นคง รายได้ดีและสวัสดิการหลากหลาย
# 7                    Salary from THB 40,401 per month
# 8        Contract 12-month with possibility to extend
# 9                Communication and Data Visualization
# 10               Competitive Salary and Good benefits
# 11  Contract 12 months with possibility for extension
# 12            12-month with possibility for extension
# 13                             ยินดีรับนักศึกษาจบใหม่
# 14               Personal security and transportation
# 15               Personal security and transportation
#
#                      Career_level                         Qualification
# 0                     Entry Level                                Degree
# 1                             Top                                Master
# 2                          Middle                                Degree
# 3                          Senior                                Degree
# 4                          Middle                                Degree
# 5                          Middle                                Degree
# 6                          Middle                                Degree
# 7                     Entry Level  Diploma of High Vocational Education
# 8                          Senior                                Degree
# 9                       Full Time                https://www.rescue.org
# 10                    Entry Level                                Degree
# 11                         Middle                                Degree
# 12                         Senior                                Degree
# 13                      Full Time         Public / Civil,Civil Services
# 14                    Entry Level                                 (N/A)
# 15  Accounting/Audit/Tax Services          More jobs from this employer

# %%
datalinks[0]
# Out:
# 'https://th.jobsdb.com//th/th/job/e-commerce-key-account-manager-300003002980938?token=0~1109cb89-cd01-431c-9e41-af2c18b129b5&sectionRank=1&jobId=jobsdb-th-job-300003002980938'

# %%
class_name = "z1s6m00 _1hbhsw64y y44q7i0 y44q7il _1d0g9qk4 y44q7is y44q7i21"
h1_tags = soup.find_all("h1", class_=class_name)

# %%
h1_tag.text
# Out:
# 'AI Machine Learning Intern'

# %%
class_name = "z1s6m00 _1hbhsw66u"
h2_tag = soup.find_all("div", class_=class_name)

# %%
# Find the span with the specific class
span = soup.find("span", class_="z1s6m00 _1hbhsw64y y44q7i0 y44q7i2 y44q7i21 _1d0g9qk4 y44q7ia")

# Extract the text from the span, if it's found
if span:
    text = span.get_text()
    print("Extracted text:", text)
else:
    print("Span with the specified class not found.")
# Out:
# Extracted text: Movefast Public Company Limited

# %%
div1 = soup.find_all("div", class_="z1s6m00 _5135ge0 _5135ge2")
jobQ = div1[1].get_text()

sentences = re.split(r'[,.:;]', jobQ)

for sentence in sentences:
    print(sentence.strip())
# Out:
# Job DescriptionJob Descriptions
# Setup the Enterprise Architecture framework for the bank
# with initial focus to set up the foundation in IT
# build the inventory for all key artifacts
# Support and facilitate the ARB (Architecture Review Board)
# Work closely with IT functional lead to drive architectural standards and provide support and tools to benefit from the enterprise architecture framework
# Job Qualifications
# Minimum 10 years of IT experienceWell verse in the Enterprise Architecture framework/practice
# Any related certification of the EA discipline will be an added advantagePractice EA or relevant discipline for at least 2 years
# Banking or Financial Institution background is preferred but not a must
# Excellent interpersonal skill in managing stakeholders and peer groups
# Bachelor/Master degree in IT or related disciplineHighly self motivated and be able to work independently

# %%
import re
# nltk.download('punkt')
sentences = re.split(r'[,.:;]', jobQ)

for sentence in sentences:
    print(sentence.strip())
# Out:
# Job DescriptionJob Descriptions
# Setup the Enterprise Architecture framework for the bank
# with initial focus to set up the foundation in IT
# build the inventory for all key artifacts
# Support and facilitate the ARB (Architecture Review Board)
# Work closely with IT functional lead to drive architectural standards and provide support and tools to benefit from the enterprise architecture framework
# Job Qualifications
# Minimum 10 years of IT experienceWell verse in the Enterprise Architecture framework/practice
# Any related certification of the EA discipline will be an added advantagePractice EA or relevant discipline for at least 2 years
# Banking or Financial Institution background is preferred but not a must
# Excellent interpersonal skill in managing stakeholders and peer groups
# Bachelor/Master degree in IT or related disciplineHighly self motivated and be able to work independently

# %%
import spacy

# Load the English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(jobQ)

# Print the sentences
for sent in doc.sents:
    print(f'{sent.text}')
# Out:
# Job DescriptionMainly responsible for the strategy and implementation of the acquiring and incubation activities for high value sellers, aiming to on-broad, grow, and ensure the success of Lazada Marketplace sellers.///
# Collaborate with Electronic Category Director/Junior Category Director to streamline our commercial’s strategy and deliver both strong and healthy growth in each sub-categoryManage workflow, work process, and call script with sales agents for daily operationAble to coordinate with cross functional team to identify issues and follow up on solutions, help team to improve performanceResearch and understand market insight to determine industry and consumer trend under Electronic category in order to deliver a strategic planning and execution for Electronic seller hunting and incubation activitiesMonitor and improve the performance of the team in terms of productivity, ensure team KPIs as requiredFacilitate training session for all agents and participate in recruitment of new agentsConduct regular review of all call center agent’s performance and organize training sessions for under performersSubmit regular tracking reports for performance update and daily outreachRequirement: 4-5 years of working experience in a management consulting, account management, sales team managementHighly motivated willing to push or go extra mile to drive impact with high ownershipStrong project management, negotiation and communication skillsExperience in leading a diverse teamFluent in Thai and proficiency in EnglishExpertise in Electronic category management is a plusExcellent analytical skills and data visualization skills, SQL would be a plusExpertise in Electronic category management is a plus///

# %%
import nltk
# nltk.download('punkt')

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

text = "Your text here."
sentences = tokenizer.tokenize(jobQ)

for sentence in sentences:
    print(sentence)
# Out:
# Job DescriptionMainly responsible for the strategy and implementation of the acquiring and incubation activities for high value sellers, aiming to on-broad, grow, and ensure the success of Lazada Marketplace sellers.Collaborate with Electronic Category Director/Junior Category Director to streamline our commercial’s strategy and deliver both strong and healthy growth in each sub-categoryManage workflow, work process, and call script with sales agents for daily operationAble to coordinate with cross functional team to identify issues and follow up on solutions, help team to improve performanceResearch and understand market insight to determine industry and consumer trend under Electronic category in order to deliver a strategic planning and execution for Electronic seller hunting and incubation activitiesMonitor and improve the performance of the team in terms of productivity, ensure team KPIs as requiredFacilitate training session for all agents and participate in recruitment of new agentsConduct regular review of all call center agent’s performance and organize training sessions for under performersSubmit regular tracking reports for performance update and daily outreachRequirement: 4-5 years of working experience in a management consulting, account management, sales team managementHighly motivated willing to push or go extra mile to drive impact with high ownershipStrong project management, negotiation and communication skillsExperience in leading a diverse teamFluent in Thai and proficiency in EnglishExpertise in Electronic category management is a plusExcellent analytical skills and data visualization skills, SQL would be a plusExpertise in Electronic category management is a plus

# %%
import spacy

# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# Your text goes here
text = '''Your long text with sentences, that may need, further splitting.'''

# Process the text
doc = nlp(jobQ)

# Define a maximum sentence length
max_length = 100  # You can adjust this value

# Store the final sentences here
final_sentences = []

# Process sentences from spaCy
for sent in doc.sents:
    # If the sentence is longer than max_length, we might want to split it further
    if len(sent.text) > max_length:
        # Further split the sentence by commas
        sub_sentences = sent.text.split(',')
        # Add non-empty sub sentences to the final list
        final_sentences.extend([sub.strip() for sub in sub_sentences if sub.strip()])
    else:
        # If sentence is shorter than max_length, add it directly
        final_sentences.append(sent.text)

# Now print the final sentences
for sentence in final_sentences:
    print(sentence)
# Out:
# Job Descriptionคุณสมบัติการศึกษาระดับ ปริญญาตรี บัญชีหรือการเงิน หรือสูงกว่ามีประสบการณ์ด้านบัญชี หรือการเงิน อย่างน้อย 3 ปี มีประสบการณ์ในการจัดทำงบการเงินรวม ด้านการวิเคราะห์ข้อมูลและรายงาน อย่างน้อย 1 ปีหากมีประสบการณ์ Auditor จะได้รับการพิจารณาเป็นกรณีพิเศษมีทักษะในการคิดวิเคราะห์ ทักษะในการนำเสนอ และมีความคิดสร้างสรรค์มีความรู้และใช้โปรแกรมคอมพิวเตอร์
# Microsoft Office และอื่น
# ๆ ได้เป็นอย่างดีมีความสามารถในการใช้ภาษาอังกฤษมีมนุษยสัมพันธ์ดี มีความสามารถในการเจรจา และสื่อสารสร้างความเข้าใจกับหน่วยงานต่าง ๆ เพื่อให้ได้รับข้อมูลที่ต้องการภายในเวลาปฏิบัติงานที่สำนักงานใหญ่ ดอนเมืองหน้าที่โดยย่อจัดทำ วิเคราะห์ และนำเสนอรายงานเพื่อการจัดการ ประมาณการ และแผนการดำเนินงานทั้งระดับบริษัท ระดับ Value Chain และระดับ BAFS
# Groupจัดทำ วิเคราะห์ และนำเสนอรายงานงบประมาณค่าใช้จ่ายบริหารและการตลาดของธุรกิจ เปรียบเทียบค่าใช้จ่ายจริงสำหรับใช้บริหารจัดการ เพื่อสนับสนุนกลยุทธ์ การขยายธุรกิจ จัดทำงบการเงินรวมตามหลักการของมาตรฐานการรายงานทางการเงินและข้อกำหนดอื่น ๆ ตามกฎหมาย ที่เกี่ยวข้อง เพื่อนำเสนอทั้งภายใน ได้แก่ คณะกรรมการบริษัท และคณะกรรมการตรวจสอบ ฝ่ายบริหาร และหน่วยงานภายนอก ได้แก่ ผู้สอบบัญชี
# ตลาดหลักทรัพย์แห่งประเทศไทย และบุคคลภายนอกอื่น ๆ สนับสนุนข้อมูลเพื่อการสื่อสารต่อนักลงทุน และการประชุมสามัญผู้ถือหุ้นประจำปี

# %%
span1 = soup.find_all("span", class_="z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 _1d0g9qk4 y44q7ia")
span1select = span1[15:19]
textspan1 = [span1.get_text(strip=True) for span1 in span1select]
for textspan in textspan1:
    print(f'{textspan}')
# Out:
# Entry Level
# Diploma of High Vocational Education
# 2 years
# Full Time, Permanent

# %%
textspan1[1]
# Out:
# 'Diploma of High Vocational Education'
